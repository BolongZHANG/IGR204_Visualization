# %%
import pandas as pd

# %%
df = pd.read_csv('TimeUseData.csv')
df
# Out:
#                         UNIT      GEO  TIME              DAYSWEEK    SEX  \
# 0         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 1         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 2         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 3         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 4         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 5         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 6         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 7         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 8         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 9         Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 10        Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# 11        Time spent (hh:mm)  Belgium  2010  All days of the week  Total
# ...

# %%
df.dtypes
# Out:
# UNIT                   object
# GEO                    object
# TIME                    int64
# DAYSWEEK               object
# SEX                    object
# ACL00                  object
# Value                  object
# Flag and Footnotes    float64
# dtype: object

# %%
pd.to_timedelta("2:45:00", unit='hh:mm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in _validate_timedelta_unit(arg)
#     130     try:
# --> 131         return _unit_map[arg]
#     132     except:
#
# KeyError: 'hh:mm'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-09149b8e5f94> in <module>()
# ----> 1 pd.to_timedelta("2:45:00", unit='hh:mm')
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in to_timedelta(arg, unit, box, errors)
#      68     pandas.to_datetime : Convert argument to datetime.
#      69     """
# ---> 70     unit = _validate_timedelta_unit(unit)
#      71
#      72     if errors not in ('ignore', 'raise', 'coerce'):
#
# ...
